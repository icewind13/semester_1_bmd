# %%
import pandas as pd
df=pd.DataFrame({
    "name":["Seraphim", "Andrew","Hannah"],
    "gender":['m','m','w'],
    "pass":[True,True,True],
    "age":[17,24,21],
    "room":[1.6,1.2,3.4],
    "house":[5,13,5]
})

# %%
df
# Out:
#        name gender  pass  age  room  house
# 0  Seraphim      m  True   17   1.6      5
# 1    Andrew      m  True   24   1.2     13
# 2    Hannah      w  True   21   3.4      5

# %%
path="C:/Users/dzt13/Documents/books.csv"
data=pd.read_csv(path,encoding='utf-8')
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import os
print("the directory is:{}".format(os.getcwd()))
# Out:
# the directory is:C:\Users\dzt13

# %%
data=pd.read_csv("books.csv")
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Out:
#              isbn13      isbn10                      title  \
# 0     9780002005883  0002005883                     Gilead
# 1     9780002261982  0002261987               Spider's Web
# 2     9780006163831  0006163831               The One Tree
# 3     9780006178736  0006178731             Rage of angels
# 4     9780006280897  0006280897             The Four Loves
# ...             ...         ...                        ...
# 6805  9788185300535  8185300534                  I Am that
# 6806  9788185944609  8185944601       Secrets Of The Heart
# 6807  9788445074879  8445074873             Fahrenheit 451
# 6808  9789027712059  9027712050   The Berlin Phenomenology
# 6809  9789042003408  9042003405  'I'm Telling You Stories'
#
#                                             subtitle  \
# 0                                                NaN
# 1                                            A Novel
# 2                                                NaN
# ...

# %%
data.shape
# Out:
# (6810, 12)

# %%
data.head
# Out:
# <bound method NDFrame.head of              isbn13      isbn10                      title  \
# 0     9780002005883  0002005883                     Gilead
# 1     9780002261982  0002261987               Spider's Web
# 2     9780006163831  0006163831               The One Tree
# 3     9780006178736  0006178731             Rage of angels
# 4     9780006280897  0006280897             The Four Loves
# ...             ...         ...                        ...
# 6805  9788185300535  8185300534                  I Am that
# 6806  9788185944609  8185944601       Secrets Of The Heart
# 6807  9788445074879  8445074873             Fahrenheit 451
# 6808  9789027712059  9027712050   The Berlin Phenomenology
# 6809  9789042003408  9042003405  'I'm Telling You Stories'
#
#                                             subtitle  \
# 0                                                NaN
# 1                                            A Novel
# 2                                                NaN
# ...

# %%
data.tail
# Out:
# <bound method NDFrame.tail of              isbn13      isbn10                      title  \
# 0     9780002005883  0002005883                     Gilead
# 1     9780002261982  0002261987               Spider's Web
# 2     9780006163831  0006163831               The One Tree
# 3     9780006178736  0006178731             Rage of angels
# 4     9780006280897  0006280897             The Four Loves
# ...             ...         ...                        ...
# 6805  9788185300535  8185300534                  I Am that
# 6806  9788185944609  8185944601       Secrets Of The Heart
# 6807  9788445074879  8445074873             Fahrenheit 451
# 6808  9789027712059  9027712050   The Berlin Phenomenology
# 6809  9789042003408  9042003405  'I'm Telling You Stories'
#
#                                             subtitle  \
# 0                                                NaN
# 1                                            A Novel
# 2                                                NaN
# ...

# %%
data.tail
# Out:
# <bound method NDFrame.tail of              isbn13      isbn10                      title  \
# 0     9780002005883  0002005883                     Gilead
# 1     9780002261982  0002261987               Spider's Web
# 2     9780006163831  0006163831               The One Tree
# 3     9780006178736  0006178731             Rage of angels
# 4     9780006280897  0006280897             The Four Loves
# ...             ...         ...                        ...
# 6805  9788185300535  8185300534                  I Am that
# 6806  9788185944609  8185944601       Secrets Of The Heart
# 6807  9788445074879  8445074873             Fahrenheit 451
# 6808  9789027712059  9027712050   The Berlin Phenomenology
# 6809  9789042003408  9042003405  'I'm Telling You Stories'
#
#                                             subtitle  \
# 0                                                NaN
# 1                                            A Novel
# 2                                                NaN
# ...

# %%
data.dtypes
# Out:
# isbn13              int64
# isbn10             object
# title              object
# subtitle           object
# authors            object
# categories         object
# thumbnail          object
# description        object
# published_year    float64
# average_rating    float64
# num_pages         float64
# ratings_count     float64
# dtype: object

# %%
data.describe()
# Out:
#              isbn13  published_year  average_rating    num_pages  \
# count  6.810000e+03     6804.000000     6767.000000  6767.000000
# mean   9.780677e+12     1998.630364        3.933284   348.181026
# std    6.068911e+08       10.484257        0.331352   242.376783
# min    9.780002e+12     1853.000000        0.000000     0.000000
# 25%    9.780330e+12     1996.000000        3.770000   208.000000
# 50%    9.780553e+12     2002.000000        3.960000   304.000000
# 75%    9.780810e+12     2005.000000        4.130000   420.000000
# max    9.789042e+12     2019.000000        5.000000  3342.000000
#
#        ratings_count
# count   6.767000e+03
# mean    2.106910e+04
# std     1.376207e+05
# min     0.000000e+00
# 25%     1.590000e+02
# 50%     1.018000e+03
# 75%     5.992500e+03
# max     5.629932e+06

# %%
data['title'].describe()
# Out:
# count                      6810
# unique                     6398
# top       The Lord of the Rings
# freq                         11
# Name: title, dtype: object

# %%
data["num_pages"].describe()
# Out:
# count    6767.000000
# mean      348.181026
# std       242.376783
# min         0.000000
# 25%       208.000000
# 50%       304.000000
# 75%       420.000000
# max      3342.000000
# Name: num_pages, dtype: float64

# %%
cut_data=data.iloc[0:10, :]
cut_data
# Out:
#           isbn13      isbn10                   title  \
# 0  9780002005883  0002005883                  Gilead
# 1  9780002261982  0002261987            Spider's Web
# 2  9780006163831  0006163831            The One Tree
# 3  9780006178736  0006178731          Rage of angels
# 4  9780006280897  0006280897          The Four Loves
# 5  9780006280934  0006280935     The Problem of Pain
# 6  9780006353287  0006353282        An Autobiography
# 7  9780006380832  0006380832  Empires of the Monsoon
# 8  9780006470229  000647022X    The Gap Into Madness
# 9  9780006472612  0006472613      Master of the Game
#
#                                          subtitle  \
# 0                                             NaN
# 1                                         A Novel
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# ...

# %%
new_data=["gr1","gr2","gr1","gr2","gr1","gr2","gr1","gr1","gr2","gr2"]
cut_data.insert(1,"Group",new_data)
cut_data
# Out:
#           isbn13 Group roup      isbn10                   title  \
# 0  9780002005883   gr1  gr1  0002005883                  Gilead
# 1  9780002261982   gr2  gr2  0002261987            Spider's Web
# 2  9780006163831   gr1  gr1  0006163831            The One Tree
# 3  9780006178736   gr2  gr2  0006178731          Rage of angels
# 4  9780006280897   gr1  gr1  0006280897          The Four Loves
# 5  9780006280934   gr2  gr2  0006280935     The Problem of Pain
# 6  9780006353287   gr1  gr1  0006353282        An Autobiography
# 7  9780006380832   gr1  gr1  0006380832  Empires of the Monsoon
# 8  9780006470229   gr2  gr2  000647022X    The Gap Into Madness
# 9  9780006472612   gr2  gr2  0006472613      Master of the Game
#
#                                          subtitle  \
# 0                                             NaN
# 1                                         A Novel
# 2                                             NaN
# 3                                             NaN
# ...

# %%
cut_data.groupby('Group').describe()
# Out:
#       isbn13                                                          \
#        count          mean           std           min           25%
# Group
# gr1      5.0  9.780005e+12  1.919857e+06  9.780002e+12  9.780006e+12
# gr2      5.0  9.780006e+12  1.832840e+06  9.780002e+12  9.780006e+12
#
#                                                 published_year          ...  \
#                 50%           75%           max          count    mean  ...
# Group                                                                   ...
# gr1    9.780006e+12  9.780006e+12  9.780006e+12            5.0  1992.6  ...
# gr2    9.780006e+12  9.780006e+12  9.780006e+12            5.0  1994.2  ...
#
#       num_pages        ratings_count                                        \
#             75%    max         count     mean           std    min     25%
# Group
# gr1       560.0  608.0           5.0   7651.4  14644.597990   65.0   172.0
# ...

# %%
cut_data.to_csv("output1.csv",encoding="utf8")
data.to_csv("output2.csv",encoding="utf8")
